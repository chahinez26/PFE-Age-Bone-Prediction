# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Fine tuning avec le dataset de Bainem sur le modèle pré-entrainé mobilenet qui à donner un MAE = 16,75 mois sur le test de RSNA

# %%
# --- Imports ---
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from datetime import datetime

# --- Paths ---
BASE_PATH = '/content/drive/MyDrive'
ANNOTATIONS_PATH = os.path.join(BASE_PATH, 'Dataset_bainem.csv')
DATA_DIR = os.path.join(BASE_PATH, 'images_bainem')
OUTPUT_DIR = os.path.join(BASE_PATH, 'bone_age_project/Models')
LOGS_DIR = os.path.join(BASE_PATH, 'bone_age_project/Logs')
MODEL_PATH = os.path.join(BASE_PATH, 'bone_age_project/Models/final_fine_tuned_model_RSNA.h5')  # ← Ton modèle

# Créer les dossiers si nécessaires
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(LOGS_DIR, exist_ok=True)

# --- Paramètres ---
BATCH_SIZE = 16
EPOCHS = 30
LEARNING_RATE = 1e-5
MAX_BONE_AGE = 216.0

# --- Fonctions de prétraitement ---
def normalize_intensity(image):
    image = tf.cast(image, tf.float32) / 255.0
    mean = tf.reduce_mean(image)
    std = tf.math.reduce_std(image)
    return (image - mean) / (std + 1e-5)

def resize_with_pad(image, target_height=224, target_width=224):
    return tf.image.resize_with_pad(image, target_height, target_width)

def data_augmentation(image):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, 0.3)
    image = tf.image.random_contrast(image, 0.6, 1.4)
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.05)
    image = tf.clip_by_value(image + noise, 0.0, 1.0)
    return image

def preprocess_image(image_path, augment=True):
    image_str = tf.io.read_file(image_path)
    image = tf.image.decode_png(image_str, channels=1)
    image = normalize_intensity(image)
    image = resize_with_pad(image)
    if augment:
        image = data_augmentation(image)
    return image

def create_dataset(dataframe, batch_size=BATCH_SIZE, augment=True):
    image_paths = [os.path.join(DATA_DIR, f"{id}.png") for id in dataframe['id']]
    ages = dataframe['boneage'].values / MAX_BONE_AGE
    genders = dataframe['male'].values.astype(np.float32)
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, (ages, genders)))
    dataset = dataset.map(lambda x, y: (preprocess_image(x, augment), y), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(buffer_size=len(dataframe))
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

def adapt_dataset_for_model(dataset):
    return dataset.map(lambda x, y: ({"image_input": x, "gender_input": tf.expand_dims(y[1], -1)}, y[0]), num_parallel_calls=tf.data.AUTOTUNE)

# --- Chargement des données ---
df = pd.read_csv(ANNOTATIONS_PATH)
df['male'] = df['male'].astype(int)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

train_ds = adapt_dataset_for_model(create_dataset(train_df, augment=True))
val_ds = adapt_dataset_for_model(create_dataset(val_df, augment=False))
test_ds = adapt_dataset_for_model(create_dataset(test_df, augment=False))

# --- Chargement du modèle MobileNetV2 préentraîné ---
model = load_model(MODEL_PATH, compile=False)
model.summary()

# Décommenter la ligne ci-dessous pour réentraîner tout le modèle :
# for layer in model.layers: layer.trainable = True

# Sinon : geler la plupart des couches
for layer in model.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='mse',
    metrics=['mae']
)

# --- Callbacks ---
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(OUTPUT_DIR, 'fine_tuned_mobilenetV1_bainem.h5'),
        monitor='val_mae', save_best_only=True, mode='min', verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_mae', factor=0.5, patience=3, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_mae', patience=8, restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.TensorBoard(
        log_dir=os.path.join(LOGS_DIR, datetime.now().strftime("%Y%m%d-%H%M%S")),
        histogram_freq=1
    )
]

# --- Entraînement ---
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# --- Sauvegarde finale ---
model.save(os.path.join(OUTPUT_DIR, 'final_finetuned_model_bainem.h5'))

# --- Visualisation des courbes ---
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Courbe de perte')
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.legend()
plt.title('Courbe MAE')
plt.tight_layout()
plt.show()

# --- Évaluation sur test ---
loss, mae = model.evaluate(test_ds, verbose=1)
print(f"\nMAE test : {mae * MAX_BONE_AGE:.2f} mois")

# --- Scatter plot vrai vs prédit ---
y_true = []
y_pred = []

for batch in test_ds:
    inputs, targets = batch
    preds = model.predict(inputs)
    y_true.extend(targets.numpy())
    y_pred.extend(preds.flatten())

y_true = np.array(y_true) * MAX_BONE_AGE
y_pred = np.array(y_pred) * MAX_BONE_AGE

plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, alpha=0.6)
plt.plot([0, MAX_BONE_AGE], [0, MAX_BONE_AGE], 'r--')
plt.xlabel("Âge osseux réel (mois)")
plt.ylabel("Âge osseux prédit (mois)")
plt.title("Vrai vs Prédit")
plt.grid(True)
plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 224, 224,  │          0 │ image_input[0][0… │
# │ (Concatenate)       │ 3)                │            │ image_input[0][0… │
# │                     │                   │            │ image_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_2… │ (None, 7, 7,      │  2,257,984 │ concatenate[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_input        │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 1281)      │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ gender_input[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    164,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,422,209 (9.24 MB)
#  Trainable params: 164,225 (641.50 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - loss: 0.0539 - mae: 0.1849
# Epoch 1: val_mae improved from inf to 0.17527, saving model to /content/drive/MyDrive/bone_age_project/Models/fine_tuned_mobilenetV1_bainem.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 0.0551 - mae: 0.1871 - val_loss: 0.0453 - val_mae: 0.1753 - learning_rate: 1.0000e-05
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.0643 - mae: 0.2180
# Epoch 2: val_mae improved from 0.17527 to 0.17471, saving model to /content/drive/MyDrive/bone_age_project/Models/fine_tuned_mobilenetV1_bainem.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 0.0639 - mae: 0.2169 - val_loss: 0.0452 - val_mae: 0.1747 - learning_rate: 1.0000e-05
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - loss: 0.0674 - mae: 0.2211
# Epoch 3: val_mae improved from 0.17471 to 0.17414, saving model to /content/drive/MyDrive/bone_age_project/Models/fine_tuned_mobilenetV1_bainem.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - loss: 0.0656 - mae: 0.2175 - val_loss: 0.0453 - val_mae: 0.1741 - learning_rate: 1.0000e-05
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - loss: 0.0660 - mae: 0.2151
# Epoch 4: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - loss: 0.0649 - mae: 0.2128 - val_loss: 0.0456 - val_mae: 0.1748 - learning_rate: 1.0000e-05
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - loss: 0.0644 - mae: 0.2092
# Epoch 5: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - loss: 0.0634 - mae: 0.2066 - val_loss: 0.0461 - val_mae: 0.1764 - learning_rate: 1.0000e-05
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.0611 - mae: 0.2063
# Epoch 6: val_mae did not improve from 0.17414
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - loss: 0.0601 - mae: 0.2045 - val_loss: 0.0466 - val_mae: 0.1777 - learning_rate: 1.0000e-05
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0500 - mae: 0.1793
# Epoch 7: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - loss: 0.0499 - mae: 0.1795 - val_loss: 0.0467 - val_mae: 0.1781 - learning_rate: 5.0000e-06
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0463 - mae: 0.1715
# Epoch 8: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - loss: 0.0465 - mae: 0.1717 - val_loss: 0.0467 - val_mae: 0.1782 - learning_rate: 5.0000e-06
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0561 - mae: 0.1907
# Epoch 9: val_mae did not improve from 0.17414
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - loss: 0.0563 - mae: 0.1915 - val_loss: 0.0466 - val_mae: 0.1778 - learning_rate: 5.0000e-06
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - loss: 0.0526 - mae: 0.1900
# Epoch 10: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - loss: 0.0525 - mae: 0.1897 - val_loss: 0.0465 - val_mae: 0.1777 - learning_rate: 2.5000e-06
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - loss: 0.0397 - mae: 0.1597
# Epoch 11: val_mae did not improve from 0.17414
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - loss: 0.0408 - mae: 0.1614 - val_loss: 0.0465 - val_mae: 0.1777 - learning_rate: 2.5000e-06
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - loss: 0.0288 - mae: 0.1394
#
# MAE test : 29.75 mois
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
